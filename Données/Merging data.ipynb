# %%
import pandas as pd

# %%
# possibilité de faire des trucs avec les mentions (colonnes BJ etc et CE etc de 2024)
list_col_2024 = ["Session", "Statut de l’établissement de la filière de formation (public, privé…)", "Établissement", "Département de l’établissement", "Région de l’établissement", "Académie de l’établissement", "Commune de l’établissement", "Filière de formation", "Sélectivité", "Filière de formation très agrégée", "Filière de formation détaillée", "Filière de formation.1", "Filière de formation détaillée bis", "Filière de formation très détaillée", "Coordonnées GPS de la formation", "Effectif total des candidats pour une formation", "Effectif total des candidats en phase principale", "Effectif des candidats néo bacheliers généraux en phase principale", "Dont effectif des candidats boursiers néo bacheliers généraux en phase principale", "Effectif des candidats néo bacheliers technologiques en phase principale", "Dont effectif des candidats boursiers néo bacheliers technologiques en phase principale", "Effectif des candidats néo bacheliers professionnels en phase principale", "Dont effectif des candidats boursiers néo bacheliers professionnels en phase principale", "Effectif total des candidats classés par l’établissement en phase principale", "Effectif des candidats néo bacheliers généraux classés par l’établissement", "Dont effectif des candidats boursiers néo bacheliers généraux classés par l’établissement", "Effectif des candidats néo bacheliers technologiques classés par l’établissement", "Dont effectif des candidats boursiers néo bacheliers technologiques classés par l’établissement", "Effectif des candidats néo bacheliers professionnels classés par l’établissement", "Dont effectif des candidats boursiers néo bacheliers professionnels classés par l’établissement", "Effectif total des candidats ayant accepté la proposition de l’établissement (admis)", "Dont effectif des admis boursiers néo bacheliers", "Effectif des admis néo bacheliers", "Effectif des admis néo bacheliers généraux", "Effectif des admis néo bacheliers technologiques", "Effectif des admis néo bacheliers professionnels", "Dont effectif des admis issus du même établissement (BTS/CPGE)", "Dont effectif des admis issus de la même académie (Paris/Créteil/Versailles réunies)", "% d’admis néo bacheliers issus de la même académie (Paris/Créteil/Versailles réunies)", "% d’admis néo bacheliers issus du même établissement (BTS/CPGE)", "% d’admis néo bacheliers boursiers", "% d’admis néo bacheliers", "% d’admis néo bacheliers généraux", "% d’admis néo bacheliers technologiques", "% d’admis néo bacheliers professionnels", "Effectif des candidats en terminale générale ayant reçu une proposition d’admission de la part de l’établissement", "Dont effectif des candidats boursiers en terminale générale ayant reçu une proposition d’admission de la part de l’établissement", "Effectif des candidats en terminale technologique ayant reçu une proposition d’admission de la part de l’établissement", "Dont effectif des candidats boursiers en terminale technologique ayant reçu une proposition d’admission de la part de l’établissement", "Effectif des candidats en terminale professionnelle ayant reçu une proposition d’admission de la part de l’établissement", "Dont effectif des candidats boursiers en terminale générale professionnelle ayant reçu une proposition d’admission de la part de l’établissement", "Taux d’accès"]

# il manque statut, commune, sélectivité
list_col_2018 = ["Session", "Établissement", "Département de l’établissement", "Région de l’établissement", "Académie de l’établissement", "Filière de formation très agrégée", "Filière de formation", "Filière de formation détaillée", "Filière de formation très détaillée", "Coordonnées GPS de la formation", "Effectif total des candidats pour une formation", "Effectif total des candidats en phase principale", "Effectif des candidats néo bacheliers généraux en phase principale", "Dont effectif des candidats boursiers néo bacheliers généraux en phase principale", "Effectif des candidats néo bacheliers technologiques en phase principale", "Dont effectif des candidats boursiers néo bacheliers technologiques en phase principale", "Effectif des candidats néo bacheliers professionnels en phase principale", "Dont effectif des candidats boursiers néo bacheliers professionnels en phase principale", "Effectif total des candidats classés par l’établissement en phase principale", "Effectif des candidats néo bacheliers généraux classés par l’établissement", "Dont effectif des candidats boursiers néo bacheliers généraux classés par l’établissement", "Effectif des candidats néo bacheliers technologiques classés par l’établissement", "Dont effectif des candidats boursiers néo bacheliers technologiques classés par l’établissement", "Effectif des candidats néo bacheliers professionnels classés par l’établissement", "Dont effectif des candidats boursiers néo bacheliers professionnels classés par l’établissement", "Effectif total des candidats ayant accepté la proposition de l’établissement (admis)", "Effectif des admis en phase principale", "Dont effectif des admis boursiers néo bacheliers", "Effectif des admis néo bacheliers", "Effectif des admis néo bacheliers généraux", "Effectif des admis néo bacheliers technologiques", "Effectif des admis néo bacheliers professionnels", "Dont effectif des admis issus du même établissement (BTS/CPGE)", "Dont effectif des admis issus de la même académie (Paris/Créteil/Versailles réunies)", "% d’admis néo bacheliers issus de la même académie (Paris/Créteil/Versailles réunies)", "% d’admis néo bacheliers issus du même établissement (BTS/CPGE)", "% d’admis néo bacheliers boursiers", "% d’admis néo bacheliers", "% d’admis néo bacheliers généraux", "% d’admis néo bacheliers technologiques", "% d’admis néo bacheliers professionnels"]
list_col_2019 = ["Session", "Statut de l’établissement de la filière de formation (public, privé…)", "Établissement", "Département de l’établissement", "Région de l’établissement", "Académie de l’établissement", "Filière de formation très agrégée", "Filière de formation", "Filière de formation détaillée", "Filière de formation très détaillée", "Coordonnées GPS de la formation", "Effectif total des candidats pour une formation", "Effectif total des candidats en phase principale", "Effectif des candidats néo bacheliers généraux en phase principale", "Dont effectif des candidats boursiers néo bacheliers généraux en phase principale", "Effectif des candidats néo bacheliers technologiques en phase principale", "Dont effectif des candidats boursiers néo bacheliers technologiques en phase principale", "Effectif des candidats néo bacheliers professionnels en phase principale", "Dont effectif des candidats boursiers néo bacheliers professionnels en phase principale", "Effectif total des candidats classés par l’établissement en phase principale", "Effectif des candidats néo bacheliers généraux classés par l’établissement", "Dont effectif des candidats boursiers néo bacheliers généraux classés par l’établissement", "Effectif des candidats néo bacheliers technologiques classés par l’établissement", "Dont effectif des candidats boursiers néo bacheliers technologiques classés par l’établissement", "Effectif des candidats néo bacheliers professionnels classés par l’établissement", "Dont effectif des candidats boursiers néo bacheliers professionnels classés par l’établissement", "Effectif total des candidats ayant accepté la proposition de l’établissement (admis)", "Effectif des admis en phase principale", "Dont effectif des admis boursiers néo bacheliers", "Effectif des admis néo bacheliers", "Effectif des admis néo bacheliers généraux", "Effectif des admis néo bacheliers technologiques", "Effectif des admis néo bacheliers professionnels", "Dont effectif des admis issus du même établissement (BTS/CPGE)", "Dont effectif des admis issus de la même académie (Paris/Créteil/Versailles réunies)", "% d’admis néo bacheliers issus de la même académie (Paris/Créteil/Versailles réunies)", "% d’admis néo bacheliers issus du même établissement (BTS/CPGE)", "% d’admis néo bacheliers boursiers", "% d’admis néo bacheliers", "% d’admis néo bacheliers généraux", "% d’admis néo bacheliers technologiques", "% d’admis néo bacheliers professionnels"]
list_col_2020 = ["Session", "Statut de l’établissement de la filière de formation (public, privé…)", "Établissement", "Département de l’établissement", "Région de l’établissement", "Académie de l’établissement", "Filière de formation très agrégée", "Filière de formation", "Filière de formation détaillée", "Filière de formation très détaillée", "Coordonnées GPS de la formation", "Effectif total des candidats pour une formation", "Effectif total des candidats en phase principale", "Effectif des candidats néo bacheliers généraux en phase principale", "Dont effectif des candidats boursiers néo bacheliers généraux en phase principale", "Effectif des candidats néo bacheliers technologiques en phase principale", "Dont effectif des candidats boursiers néo bacheliers technologiques en phase principale", "Effectif des candidats néo bacheliers professionnels en phase principale", "Dont effectif des candidats boursiers néo bacheliers professionnels en phase principale", "Effectif total des candidats classés par l’établissement en phase principale", "Effectif des candidats néo bacheliers généraux classés par l’établissement", "Dont effectif des candidats boursiers néo bacheliers généraux classés par l’établissement", "Effectif des candidats néo bacheliers technologiques classés par l’établissement", "Dont effectif des candidats boursiers néo bacheliers technologiques classés par l’établissement", "Effectif des candidats néo bacheliers professionnels classés par l’établissement", "Dont effectif des candidats boursiers néo bacheliers professionnels classés par l’établissement", "Effectif total des candidats ayant accepté la proposition de l’établissement (admis)", "Effectif des admis en phase principale", "Dont effectif des admis boursiers néo bacheliers", "Effectif des admis néo bacheliers", "Effectif des admis néo bacheliers généraux", "Effectif des admis néo bacheliers technologiques", "Effectif des admis néo bacheliers professionnels", "Dont effectif des admis issus du même établissement (BTS/CPGE)", "Dont effectif des admis issus de la même académie (Paris/Créteil/Versailles réunies)", "% d’admis néo bacheliers issus de la même académie (Paris/Créteil/Versailles réunies)", "% d’admis néo bacheliers issus du même établissement (BTS/CPGE)", "% d’admis néo bacheliers boursiers", "% d’admis néo bacheliers", "% d’admis néo bacheliers généraux", "% d’admis néo bacheliers technologiques", "% d’admis néo bacheliers professionnels", "Sélectivité", "Filière de formation détaillée.1", "Indicateur Parcoursup du taux d’accès des candidats ayant postulé à la formation (ratio entre le dernier appelé et le dernier classé)"]
list_col_2021 = ["Session", "Statut de l’établissement de la filière de formation (public, privé…)", "Établissement", "Département de l’établissement", "Région de l’établissement", "Académie de l’établissement", "Commune de l’établissement", "Filière de formation", "Sélectivité", "Filière de formation très agrégée", "Filière de formation détaillée", "Filière de formation.1", "Filière de formation détaillée bis", "Filière de formation très détaillée", "Coordonnées GPS de la formation", "Effectif total des candidats pour une formation", "Effectif total des candidats en phase principale", "Effectif des candidats néo bacheliers généraux en phase principale", "Dont effectif des candidats boursiers néo bacheliers généraux en phase principale", "Effectif des candidats néo bacheliers technologiques en phase principale", "Dont effectif des candidats boursiers néo bacheliers technologiques en phase principale", "Effectif des candidats néo bacheliers professionnels en phase principale", "Dont effectif des candidats boursiers néo bacheliers professionnels en phase principale", "Effectif total des candidats classés par l’établissement en phase principale", "Effectif des candidats néo bacheliers généraux classés par l’établissement", "Dont effectif des candidats boursiers néo bacheliers généraux classés par l’établissement", "Effectif des candidats néo bacheliers technologiques classés par l’établissement", "Dont effectif des candidats boursiers néo bacheliers technologiques classés par l’établissement", "Effectif des candidats néo bacheliers professionnels classés par l’établissement", "Dont effectif des candidats boursiers néo bacheliers professionnels classés par l’établissement", "Effectif total des candidats ayant accepté la proposition de l’établissement (admis)", "Dont effectif des admis boursiers néo bacheliers", "Effectif des admis néo bacheliers", "Effectif des admis néo bacheliers généraux", "Effectif des admis néo bacheliers technologiques", "Effectif des admis néo bacheliers professionnels", "Dont effectif des admis issus du même établissement (BTS/CPGE)", "Dont effectif des admis issus de la même académie (Paris/Créteil/Versailles réunies)", "% d’admis néo bacheliers issus de la même académie (Paris/Créteil/Versailles réunies)", "% d’admis néo bacheliers issus du même établissement (BTS/CPGE)", "% d’admis néo bacheliers boursiers", "% d’admis néo bacheliers", "% d’admis néo bacheliers généraux", "% d’admis néo bacheliers technologiques", "% d’admis néo bacheliers professionnels", "Effectif des candidats en terminale générale ayant reçu une proposition d’admission de la part de l’établissement", "Dont effectif des candidats boursiers en terminale générale ayant reçu une proposition d’admission de la part de l’établissement", "Effectif des candidats en terminale technologique ayant reçu une proposition d’admission de la part de l’établissement", "Dont effectif des candidats boursiers en terminale technologique ayant reçu une proposition d’admission de la part de l’établissement", "Effectif des candidats en terminale professionnelle ayant reçu une proposition d’admission de la part de l’établissement", "Dont effectif des candidats boursiers en terminale générale professionnelle ayant reçu une proposition d’admission de la part de l’établissement", "Taux d’accès des candidats ayant postulé à la formation (ratio entre le dernier appelé et le nombre vœux PP)"]
list_col_2022 = list_col_2023 = list_col_2024

# %%
df_2018 = pd.read_csv("fr-esr-parcoursup_2018.csv", sep=";", encoding="utf-8", usecols=list_col_2018)
df_2019 = pd.read_csv("fr-esr-parcoursup_2019.csv", sep=";", encoding="utf-8", usecols=list_col_2019)
df_2020 = pd.read_csv("fr-esr-parcoursup_2020.csv", sep=";", encoding="utf-8", usecols=list_col_2020)
df_2020.rename(columns={"Indicateur Parcoursup du taux d’accès des candidats ayant postulé à la formation (ratio entre le dernier appelé et le dernier classé)": "Taux d’accès"}, inplace=True)
df_2021 = pd.read_csv("fr-esr-parcoursup_2021.csv", sep=";", encoding="utf-8", usecols=list_col_2021)
df_2021.rename(columns={"Taux d’accès des candidats ayant postulé à la formation (ratio entre le dernier appelé et le nombre vœux PP)": "Taux d’accès"}, inplace=True)
df_2022 = pd.read_csv("fr-esr-parcoursup_2022.csv", sep=";", encoding="utf-8", usecols=list_col_2022)
df_2023 = pd.read_csv("fr-esr-parcoursup_2023.csv", sep=";", encoding="utf-8", usecols=list_col_2023)
df_2024 = pd.read_csv("fr-esr-parcoursup_2024.csv", sep=";", encoding="utf-8", usecols=list_col_2024)

# %%
df = pd.concat([df_2018, df_2019, df_2020, df_2021, df_2022, df_2023, df_2024])

# %%
df
# Out:
#        Session                                      Établissement  \
# 0         2018    Université Grenoble Alpes - Antennes de Valence
# 1         2018              Universite Jean Monnet, Saint-Etienne
# 2         2018                      Université Jean Moulin Lyon 3
# 3         2018                      Université Jean Moulin Lyon 3
# 4         2018                      Université Jean Moulin Lyon 3
# ...        ...                                                ...
# 14074     2024  Institut d'études politiques de Paris - Scienc...
# 14075     2024       Université de Bretagne Sud - Site de Lorient
# 14076     2024                      Université Bordeaux Montaigne
# 14077     2024     Ecole management Strasbourg - Site de Mulhouse
# 14078     2024            Kedge Business School de Mont de Marsan
#
#       Département de l’établissement Région de l’établissement  \
# 0                              Drôme      Auvergne-Rhône-Alpes
# ...

# %%
df.to_csv("fr-esr-parcoursup_2018-2024.csv", sep=";", encoding="utf-8", index=False)
